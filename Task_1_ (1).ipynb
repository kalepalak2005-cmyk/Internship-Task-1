# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
import datetime

# %%
# Importing Customer behaviour data
data=pd.read_csv('CUSTOMERADATA.csv')
data
# Out:
#         Customer ID     Purchase Date Product Category  Product Price  \
# 0             46251  08-09-2020 09:38      Electronics             12
# 1             46251  05-03-2022 12:56             Home            468
# 2             46251  23-05-2022 18:18             Home            288
# 3             46251  12-11-2020 13:13         Clothing            196
# 4             13593  27-11-2020 17:55             Home            449
# ...             ...               ...              ...            ...
# 249995        33308  10-08-2023 13:39         Clothing            279
# 249996        48835  23-11-2021 01:30             Home             27
# 249997        21019  02-07-2020 14:04             Home             17
# 249998        49234  30-12-2020 02:02            Books            398
# 249999        16971  13-03-2021 16:28      Electronics            425
#
#         Quantity  Total Purchase Amount Payment Method  Customer Age  Returns  \
# 0              3                    740    Credit Card            37      0.0
# 1              4                   2739         PayPal            37      0.0
# 2              2                   3196         PayPal            37      0.0
# 3              1                   3509         PayPal            37      0.0
# 4              1                   3452    Credit Card            49      0.0
# ...          ...                    ...            ...           ...      ...
# 249995         2                   2187         PayPal            55      1.0
# 249996         1                   3615    Credit Card            42      1.0
# 249997         5                   2466           Cash            41      0.0
# 249998         2                   3668         Crypto            34      0.0
# 249999         4                   2370           Cash            36      1.0
#
#               Customer Name  Age  Gender  Churn
# 0       Christine Hernandez   37    Male      0
# 1       Christine Hernandez   37    Male      0
# 2       Christine Hernandez   37    Male      0
# 3       Christine Hernandez   37    Male      0
# 4               James Grant   49  Female      1
# ...                     ...  ...     ...    ...
# 249995      Michelle Flores   55    Male      1
# 249996          Jeremy Rush   42  Female      1
# 249997           Tina Craig   41    Male      0
# 249998      Jennifer Cooper   34  Female      1
# 249999        Justin Lawson   36  Female      1
#
# [250000 rows x 13 columns]

# %%
data.head(10)
# Out:
#    Customer ID     Purchase Date Product Category  Product Price  Quantity  \
# 0        46251  08-09-2020 09:38      Electronics             12         3
# 1        46251  05-03-2022 12:56             Home            468         4
# 2        46251  23-05-2022 18:18             Home            288         2
# 3        46251  12-11-2020 13:13         Clothing            196         1
# 4        13593  27-11-2020 17:55             Home            449         1
# 5        13593  07-03-2023 14:17             Home            250         4
# 6        13593  15-04-2023 03:02      Electronics             73         1
# 7        13593  27-03-2021 21:23            Books            337         2
# 8        13593  05-05-2020 20:14         Clothing            182         2
# 9        28805  13-09-2023 04:24      Electronics            394         2
#
#    Total Purchase Amount Payment Method  Customer Age  Returns  \
# 0                    740    Credit Card            37      0.0
# 1                   2739         PayPal            37      0.0
# 2                   3196         PayPal            37      0.0
# 3                   3509         PayPal            37      0.0
# 4                   3452    Credit Card            49      0.0
# 5                    575         PayPal            49      1.0
# 6                   1896    Credit Card            49      0.0
# 7                   2937           Cash            49      0.0
# 8                   3363         PayPal            49      1.0
# 9                   1993    Credit Card            19      0.0
#
#          Customer Name  Age  Gender  Churn
# 0  Christine Hernandez   37    Male      0
# 1  Christine Hernandez   37    Male      0
# 2  Christine Hernandez   37    Male      0
# 3  Christine Hernandez   37    Male      0
# 4          James Grant   49  Female      1
# 5          James Grant   49  Female      1
# 6          James Grant   49  Female      1
# 7          James Grant   49  Female      1
# 8          James Grant   49  Female      1
# 9         Jose Collier   19    Male      0

# %% [markdown]
# EDA and Data Cleaning

# %%
#Details of the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Customer ID            250000 non-null  int64
#  1   Purchase Date          250000 non-null  object
#  2   Product Category       250000 non-null  object
#  3   Product Price          250000 non-null  int64
#  4   Quantity               250000 non-null  int64
#  5   Total Purchase Amount  250000 non-null  int64
#  6   Payment Method         250000 non-null  object
#  7   Customer Age           250000 non-null  int64
#  8   Returns                202404 non-null  float64
#  9   Customer Name          250000 non-null  object
#  10  Age                    250000 non-null  int64
#  11  Gender                 250000 non-null  object
#  12  Churn                  250000 non-null  int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 24.8+ MB

# %%
# Converting Datatype from object to datetime
data['Purchase Date']=pd.to_datetime(data['Purchase Date'],errors='coerce')

# %%
# Details of the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Customer ID            250000 non-null  int64
#  1   Purchase Date          99828 non-null   datetime64[ns]
#  2   Product Category       250000 non-null  object
#  3   Product Price          250000 non-null  int64
#  4   Quantity               250000 non-null  int64
#  5   Total Purchase Amount  250000 non-null  int64
#  6   Payment Method         250000 non-null  object
#  7   Customer Age           250000 non-null  int64
#  8   Returns                202404 non-null  float64
#  9   Customer Name          250000 non-null  object
#  10  Age                    250000 non-null  int64
#  11  Gender                 250000 non-null  object
#  12  Churn                  250000 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(7), object(4)
# memory usage: 24.8+ MB

# %%
# Checking for null values

# %%
data.isnull().sum()
# Out:
# Customer ID                   0
# Purchase Date            150172
# Product Category              0
# Product Price                 0
# Quantity                      0
# Total Purchase Amount         0
# Payment Method                0
# Customer Age                  0
# Returns                   47596
# Customer Name                 0
# Age                           0
# Gender                        0
# Churn                         0
# dtype: int64

# %%
# Statistical Summary
data.describe()
# Out:
#         Customer ID                  Purchase Date  Product Price  \
# count  250000.00000                          99828  250000.000000
# mean    25004.03624  2021-11-15 20:03:47.823055872     254.659512
# min         1.00000            2020-01-01 00:15:00      10.000000
# 25%     12497.75000            2020-12-03 03:33:00     132.000000
# 50%     25018.00000            2021-11-07 17:09:30     255.000000
# 75%     37506.00000            2022-10-10 09:53:45     377.000000
# max     50000.00000            2023-12-09 23:51:00     500.000000
# std     14428.27959                            NaN     141.568577
#
#             Quantity  Total Purchase Amount   Customer Age        Returns  \
# count  250000.000000          250000.000000  250000.000000  202404.000000
# mean        2.998896            2725.370732      43.940528       0.497861
# min         1.000000             100.000000      18.000000       0.000000
# 25%         2.000000            1477.000000      31.000000       0.000000
# 50%         3.000000            2724.000000      44.000000       0.000000
# 75%         4.000000            3974.000000      57.000000       1.000000
# max         5.000000            5350.000000      70.000000       1.000000
# std         1.414694            1442.933565      15.350246       0.499997
#
#                  Age          Churn
# count  250000.000000  250000.000000
# mean       43.940528       0.199496
# min        18.000000       0.000000
# 25%        31.000000       0.000000
# 50%        44.000000       0.000000
# 75%        57.000000       0.000000
# max        70.000000       1.000000
# std        15.350246       0.399622

# %%
# Filling null values by mean
data=data.fillna('mean')
data
# Out:
#         Customer ID        Purchase Date Product Category  Product Price  \
# 0             46251  2020-08-09 09:38:00      Electronics             12
# 1             46251  2022-05-03 12:56:00             Home            468
# 2             46251                 mean             Home            288
# 3             46251  2020-12-11 13:13:00         Clothing            196
# 4             13593                 mean             Home            449
# ...             ...                  ...              ...            ...
# 249995        33308  2023-10-08 13:39:00         Clothing            279
# 249996        48835                 mean             Home             27
# 249997        21019  2020-02-07 14:04:00             Home             17
# 249998        49234                 mean            Books            398
# 249999        16971                 mean      Electronics            425
#
#         Quantity  Total Purchase Amount Payment Method  Customer Age Returns  \
# 0              3                    740    Credit Card            37     0.0
# 1              4                   2739         PayPal            37     0.0
# 2              2                   3196         PayPal            37     0.0
# 3              1                   3509         PayPal            37     0.0
# 4              1                   3452    Credit Card            49     0.0
# ...          ...                    ...            ...           ...     ...
# 249995         2                   2187         PayPal            55     1.0
# 249996         1                   3615    Credit Card            42     1.0
# 249997         5                   2466           Cash            41     0.0
# 249998         2                   3668         Crypto            34     0.0
# 249999         4                   2370           Cash            36     1.0
#
#               Customer Name  Age  Gender  Churn
# 0       Christine Hernandez   37    Male      0
# 1       Christine Hernandez   37    Male      0
# 2       Christine Hernandez   37    Male      0
# 3       Christine Hernandez   37    Male      0
# 4               James Grant   49  Female      1
# ...                     ...  ...     ...    ...
# 249995      Michelle Flores   55    Male      1
# 249996          Jeremy Rush   42  Female      1
# 249997           Tina Craig   41    Male      0
# 249998      Jennifer Cooper   34  Female      1
# 249999        Justin Lawson   36  Female      1
#
# [250000 rows x 13 columns]

# %%
data.isnull().sum()
# Out:
# Customer ID              0
# Purchase Date            0
# Product Category         0
# Product Price            0
# Quantity                 0
# Total Purchase Amount    0
# Payment Method           0
# Customer Age             0
# Returns                  0
# Customer Name            0
# Age                      0
# Gender                   0
# Churn                    0
# dtype: int64

# %%
# Checking duplicate values
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Importing Data

# %%
data.describe(include='O')
# Out:
#        Purchase Date Product Category Payment Method   Returns  Customer Name  \
# count         250000           250000         250000  250000.0         250000
# unique         93724                4              4       3.0          39920
# top             mean         Clothing    Credit Card       0.0  Michael Smith
# freq          150172            75052         100486  101635.0            107
#
#         Gender
# count   250000
# unique       2
# top     Female
# freq    125560

# %%
data.describe(include='all')
# Out:
#          Customer ID Purchase Date Product Category  Product Price  \
# count   250000.00000        250000           250000  250000.000000
# unique           NaN         93724                4            NaN
# top              NaN          mean         Clothing            NaN
# freq             NaN        150172            75052            NaN
# mean     25004.03624           NaN              NaN     254.659512
# std      14428.27959           NaN              NaN     141.568577
# min          1.00000           NaN              NaN      10.000000
# 25%      12497.75000           NaN              NaN     132.000000
# 50%      25018.00000           NaN              NaN     255.000000
# 75%      37506.00000           NaN              NaN     377.000000
# max      50000.00000           NaN              NaN     500.000000
#
#              Quantity  Total Purchase Amount Payment Method   Customer Age  \
# count   250000.000000          250000.000000         250000  250000.000000
# unique            NaN                    NaN              4            NaN
# top               NaN                    NaN    Credit Card            NaN
# freq              NaN                    NaN         100486            NaN
# mean         2.998896            2725.370732            NaN      43.940528
# std          1.414694            1442.933565            NaN      15.350246
# min          1.000000             100.000000            NaN      18.000000
# 25%          2.000000            1477.000000            NaN      31.000000
# 50%          3.000000            2724.000000            NaN      44.000000
# 75%          4.000000            3974.000000            NaN      57.000000
# max          5.000000            5350.000000            NaN      70.000000
#
#          Returns  Customer Name            Age  Gender          Churn
# count   250000.0         250000  250000.000000  250000  250000.000000
# unique       3.0          39920            NaN       2            NaN
# top          0.0  Michael Smith            NaN  Female            NaN
# freq    101635.0            107            NaN  125560            NaN
# mean         NaN            NaN      43.940528     NaN       0.199496
# std          NaN            NaN      15.350246     NaN       0.399622
# min          NaN            NaN      18.000000     NaN       0.000000
# 25%          NaN            NaN      31.000000     NaN       0.000000
# 50%          NaN            NaN      44.000000     NaN       0.000000
# 75%          NaN            NaN      57.000000     NaN       0.000000
# max          NaN            NaN      70.000000     NaN       1.000000

# %% [markdown]
# Feature Engineering
#
# Creating RFM Table
#
# R = Recency, F = Frequency, M = Monetary

# %%
# Creating RFM Table
# Ensure 'Purchase Date' is datetime, handling any 'mean' strings introduced previously
data['Purchase Date'] = pd.to_datetime(data['Purchase Date'], errors='coerce')

# Fill NaT values (introduced by coerce or previous NaTs) with the median date
# This is a common strategy when dates are required for calculations
# Calculate median date only from non-null datetime values
median_date = data['Purchase Date'].dropna().median()
data['Purchase Date'] = data['Purchase Date'].fillna(median_date)

data['Year']=data['Purchase Date'].dt.year
data['Month']=data['Purchase Date'].dt.month
data['DayOfDate']=data['Purchase Date'].dt.day_name()

# %%
# Reference date to calculate Recency
snapshot_date=data['Purchase Date'].max()+pd.Timedelta(days=1)

# %% [markdown]
# Finds the most recent purchase date in the dataset.
#
# Adds 1 day to it.
#
# Why add 1 day?
#
# -> To avoid Recency = 0 for customers who purchased on the last date.

# %%
# RFM Table creation
rfm=data.groupby('Customer ID').agg({
    'Purchase Date': lambda x: (snapshot_date - x.max()).days,
    'Customer ID': 'count',
    'Total Purchase Amount': 'sum'
})

# %%
# Rename RFM columns
rfm.columns=['Recency','Frequency','Monetary']

# %% [markdown]
# Converting raw RFM values(Recency, frequecy, Monetary) into scores

# %%
rfm['R_Score']=pd.qcut(rfm['Recency'],4,labels=False,duplicates='drop')
rfm['F_Score']=pd.qcut(rfm['Frequency'],4,labels=False,duplicates='drop')
rfm['M_Score']=pd.qcut(rfm['Monetary'],4,labels=False,duplicates='drop')

rfm['RFM_Score']=rfm[['R_Score','F_Score','M_Score']].sum(axis=1)

rfm
# Out:
#              Recency  Frequency  Monetary  R_Score  F_Score  M_Score  \
# Customer ID
# 1                763          1      3491        2        0        0
# 2                763          3      7988        2        0        0
# 3                763          8     22587        2        3        3
# 4                  5          4      8715        0        1        0
# 5                763          8     12524        2        3        1
# ...              ...        ...       ...      ...      ...      ...
# 49996            763          4     14044        2        1        2
# 49997            638          8     22431        2        3        3
# 49998            245          4      8610        0        1        0
# 49999            763          2      6984        2        0        0
# 50000             35          2      4116        0        0        0
#
#              RFM_Score
# Customer ID
# 1                    2
# 2                    2
# 3                    8
# 4                    1
# 5                    6
# ...                ...
# 49996                5
# 49997                8
# 49998                1
# 49999                2
# 50000                0
#
# [49673 rows x 7 columns]

# %% [markdown]
# ### Profiling Customer Segments
#
# 1.   Creating RFM based segments

# %%
def rfm_segment(row):
    if row['RFM_Score'] >= 8:
        return 'Champions'
    elif row['RFM_Score'] >= 6:
        return 'Loyal Customers'
    elif row['RFM_Score'] >= 4:
        return 'Potential Loyalists'
    elif row['RFM_Score'] >= 2:
        return 'At-Risk'
    else:
        return 'Lost Customers'

rfm['Segment'] = rfm.apply(rfm_segment, axis=1)

# %% [markdown]
# ### 2.   Profiling Each Segment

# %%
segment_profile = rfm.groupby('Segment').agg({
    'Recency': 'mean',
    'Frequency': 'mean',
    'Monetary': 'mean',
    'RFM_Score': 'mean',
    'Segment': 'count'
}).rename(columns={'Segment':'Customer_Count'})

segment_profile
# Out:
#                         Recency  Frequency      Monetary  RFM_Score  \
# Segment
# At-Risk              555.293319   3.322981   8427.511116   2.446334
# Champions            711.551698   8.017544  23380.458753   8.000000
# Lost Customers       232.219596   2.783590   6405.692246   0.666490
# Loyal Customers      413.915664   7.488092  21204.319420   6.401536
# Potential Loyalists  527.316044   5.114798  14069.246885   4.462691
#
#                      Customer_Count
# Segment
# At-Risk                       17227
# Champions                      2679
# Lost Customers                 3766
# Loyal Customers               11715
# Potential Loyalists           14286

# %% [markdown]
# 1. Champions
#
# Low recency → purchased recently
#
# High frequency → buy often
#
# High monetary value → spend more
#
# Business meaning: Most valuable customers
#
# 2. Loyal Customers
#
# Purchase frequently but not always recently
#
# Medium–high spending
#
# Stable revenue contributors
#
# 3. Potential Loyalists
#
# Recent buyers
#
# Moderate purchase frequency
#
# Medium spending
#
# 4. At-Risk Customers
#
# Long time since last purchase
#
# Previously good spenders
#
# Declining engagement
#
# 5. Lost Customers
#
# Very high recency (inactive)
#
# Low frequency
#
# Low spending

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(x='Segment',y='Monetary', data=rfm)
plt.xticks(rotation=45)
plt.title("Monetary Value by Customer Segment")
plt.show()

# %% [markdown]
# Conclusion:- sgfuAGiugsfuiasgiun

# %% [markdown]
# A. Purchase Patterns

# %%
# Line Plot
import seaborn as sns
sns.lineplot(data=data,x='Month',y='Total Purchase Amount',estimator='sum')
# Out:
# <Axes: xlabel='Month', ylabel='Total Purchase Amount'>

# %% [markdown]
# Conclusion:-

# %% [markdown]
# B. Category Preferences

# %%
#bar plot
data.groupby('Product Category')['Total Purchase Amount'].sum().sort_values().plot(kind='barh')
# Out:
# <Axes: ylabel='Product Category'>

# %% [markdown]
# Conclusion:-

# %% [markdown]
# C. Month-over-Month Repeat Buyers (Retention Trend)

# %%
# Creating Year-Month column
data['YearMonth'] = data['Purchase Date'].dt.to_period('M')

# Count unique customers per month
monthly_customers = (
    data.groupby('YearMonth')['Customer ID']
    .nunique()
    .reset_index()
)

monthly_customers['YearMonth'] = monthly_customers['YearMonth'].astype(str)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(monthly_customers['YearMonth'], monthly_customers['Customer ID'], marker='o')
plt.xticks(rotation=45)
plt.title('Month-over-Month Active Customers')
plt.xlabel('Month')
plt.ylabel('Number of Active Customers')
plt.grid(True)
plt.show()

# %% [markdown]
# conclusion:-

# %% [markdown]
# D. Churn Flag – No Purchase in Last X Months

# %%
snapshot_date = data['Purchase Date'].max()
churn_months = 3

# Last Purchase per customer
last_purchase = data.groupby('Customer ID')['Purchase Date'].max().reset_index()

# Create churn flag
last_purchase['Months_Since_Last_Purchase'] = (
    (snapshot_date - last_purchase['Purchase Date']) / pd.Timedelta(days=30)
)

last_purchase['Churn_Flag'] = last_purchase['Months_Since_Last_Purchase'] > churn_months

# Count churned vs active customers
churn_counts = last_purchase['Churn_Flag'].value_counts().reset_index()
churn_counts.columns = ['Churn_Flag', 'Customer_Count']

# %%
# Plot churn distribution
plt.figure(figsize=(6,4))
plt.bar(churn_counts['Churn_Flag'].astype(str), churn_counts['Customer_Count'])
plt.title('Customer Churn Distribution')
plt.xlabel('Churn Status (True = Churned)')
plt.ylabel('Number of Customers')
plt.show()

# %% [markdown]
# Conclusion:-

# %% [markdown]
# # Retention & Loyalty Analysis

# %%
last_purchase = data.groupby("Customer ID")['Purchase Date'].max().reset_index()
last_purchase['Churn'] = last_purchase['Purchase Date'] < pd.to_datetime("2025-01-01")

# %%
last_purchase['Churn'][2]
# Out:
# np.True_
